# %% [markdown]
# <a href="https://colab.research.google.com/github/jgutier1/CLASE_PRO_ANA_DATOS_8/blob/main/Funcion_Seno_24_nov_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

plt.plot(x, y,color='yellow', linewidth=3)

plt.xlabel("x")
plt.ylabel("sin(x)")

plt.title("Grafica Función Seno")

plt.grid(True)
plt.show()
